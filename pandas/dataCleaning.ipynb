# %%
import pandas as pd 

df = pd.read_csv("Map-Scraper_20260826125140.csv")

print(df.columns)
# Out:
# Index(['ID', 'Name', 'Address', 'Featured image', 'Bing Maps URL', 'Latitude',
#        'Longitude', 'Rating', 'Rating Info', 'Category', 'Open Hours',
#        'Scraped At', 'Website', 'Phone', 'Social Medias', 'Facebook',
#        'Instagram', 'Twitter', 'Emails'],
#       dtype='str')

# %%
df = df[["Name", "Address", "Phone", "Instagram", "Twitter", "Emails"]]
print(df)
# Out:
#                                                  Name  \
# 0                               Cloves Indian Cuisine
# 1                             Anjappar Indian Cuisine
# 2                                Dhaba Indian Cuisine
# 3                       Carmine's - 44th Street - NYC
# 4                                             GupShup
# 5                               India At Times Square
# 6                                              Upland
# 7                           Saar Indian Cuisine & Bar
# 8          Lungi South Indian & Sri Lankan Restaurant
# 9                                     Kellari Taverna
# 10                                       Darbar Grill
# 11                                              Becco
# 12                      Socarrat Paella Bar - Chelsea
# 13                                             ROBERT
# 14                    Delhi Heights Indian Restaurant
# 15                                             Mantra
# ...

# %%
df = df[df["Emails"].str.contains("@gmail.com", na=False)]
df.drop_duplicates()
# Out:
#                                                  Name  \
# 0                               Cloves Indian Cuisine
# 1                             Anjappar Indian Cuisine
# 5                               India At Times Square
# 7                           Saar Indian Cuisine & Bar
# 14                    Delhi Heights Indian Restaurant
# 16                                         Chez Oskar
# 27                             Court Square Dentistry
# 29                                  Elephant District
# 34                                         Da Gennaro
# 37  Dentist in Stamford CT - Supreme Dentist Stamf...
#
#                                              Address           Phone  \
# 0                 66 Madison Ave, New York, NY 10016  (646) 398-9444
# 1              116 Lexington Ave, New York, NY 10016  (917) 540-5287
# 5                  332 W 44th St, New York, NY 10036  (646) 476-4356
# 7                  241 W 51st St, New York, NY 10019  (646) 609-2142
# ...
